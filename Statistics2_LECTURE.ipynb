# %% [markdown]
# <a href="https://colab.research.google.com/github/Bayaniblues/Lambda-precourse/blob/master/Statistics2_LECTURE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # Lambda School Data Science - Intro to Statistics
# ---
# # Lecture 10 - Descriptive Statistics 2
# ---

# %% [markdown]
# ## Correlation
#
# You've probably heard people describe two things as *correlated* -- but what does that mean exactly? Well, correlation is basically whether or not two variables move in the same direction. It is yet another descriptive statistic that can help us get a sense of what a set of values looks like.

# %%
# Let's begin by importing our tools:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Now let's bring in our dataset of MPG data:

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/mpg.csv")
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model-year
# 0  18.0          8         307.0       130.0    3504          12.0          70
# 1  15.0          8         350.0       165.0    3693          11.5          70
# 2  18.0          8         318.0       150.0    3436          11.0          70
# 3  16.0          8         304.0       150.0    3433          12.0          70
# 4  17.0          8         302.0       140.0    3449          10.5          70

# %% [markdown]
# ### What does the relationship between the values look like?
#
# MPG (miles per gallon) is a measure of a car's fuel efficiency. Basically, how much distance can it travel per unit of fuel. Let's see if there are any relationships between MPG and the other features.

# %%
# Create the plot
df.plot.scatter(x='mpg', y='cylinders');
# plt.show()

# In case you forgot, adding a ';' at the end hides some extra info that comes with the plot.
# Feel free to remove it to see for yourself!

# %%
df.plot.scatter(x='mpg', y='displacement');

# %%
df.plot.scatter(x='mpg', y='horsepower');

# %%
df.plot.scatter(x='mpg', y='weight');

# %%
df.plot.scatter(x='mpg', y='acceleration');

# %%
df.plot.scatter(x='mpg', y='model-year');

# %% [markdown]
# ### Measuring the relationship between variables:
#
# **Pearson correlation coefficient**

# %% [markdown]
# $\rho = \frac{\text{cov}(X,Y)}{\sigma_x \sigma_y}$

# %% [markdown]
# **Don't worry too much about the above formula for now. We'll go deeper into the math later on in the course. For now, just understand this:**
#
# A value of:
# * 1 represents a perfect positive relationship
# * -1 represents a perfect negative relationship
# * 0 indicates the absence of a relationship between variables.

# %%
# Here's a way to see the correlation coefficients of all the features:
df.corr()
# Out:
#                    mpg  cylinders  ...  acceleration  model-year
# mpg           1.000000  -0.775396  ...      0.420289    0.579267
# cylinders    -0.775396   1.000000  ...     -0.505419   -0.348746
# displacement -0.804203   0.950721  ...     -0.543684   -0.370164
# horsepower   -0.777575   0.843751  ...     -0.687241   -0.420697
# weight       -0.831741   0.896017  ...     -0.417457   -0.306564
# acceleration  0.420289  -0.505419  ...      1.000000    0.288137
# model-year    0.579267  -0.348746  ...      0.288137    1.000000
#
# [7 rows x 7 columns]

# %% [markdown]
# DataFrame.Corr() [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html).

# %% [markdown]
# ### To recap:
#
#
#
# *   **Central tendency** is basically the value most representative of a group of values.
# *   **Variability** tells you how spread out (or different) your values are from one another.
# *   **Correlation** gives you an idea of the relationship between two variables. Namely, how do they move relative to one another.
# *   **Correlation coefficient** gives you a measure, between 0 and 1, of how correlated two variables are.

# %% [markdown]
# ### Time to put all this together in your assignment!
